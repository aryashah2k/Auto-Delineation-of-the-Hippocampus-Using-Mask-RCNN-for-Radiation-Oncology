# %%
import matplotlib.pyplot as plt
import numpy as np

def img_is_color(img):

    if len(img.shape) == 3:
        # Check the color channels to see if they're all the same.
        c1, c2, c3 = img[:, : , 0], img[:, :, 1], img[:, :, 2]
        if (c1 == c2).all() and (c2 == c3).all():
            return True

    return False

def show_image_list(list_images, list_titles=None, list_cmaps=None, grid=True, num_cols=2, figsize=(20, 10), title_fontsize=30):
    '''
    Shows a grid of images, where each image is a Numpy array. The images can be either
    RGB or grayscale.

    Parameters:
    ----------
    images: list
        List of the images to be displayed.
    list_titles: list or None
        Optional list of titles to be shown for each image.
    list_cmaps: list or None
        Optional list of cmap values for each image. If None, then cmap will be
        automatically inferred.
    grid: boolean
        If True, show a grid over each image
    num_cols: int
        Number of columns to show.
    figsize: tuple of width, height
        Value to be passed to pyplot.figure()
    title_fontsize: int
        Value to be passed to set_title().
    '''

    assert isinstance(list_images, list)
    assert len(list_images) > 0
    assert isinstance(list_images[0], np.ndarray)

    if list_titles is not None:
        assert isinstance(list_titles, list)
        assert len(list_images) == len(list_titles), '%d imgs != %d titles' % (len(list_images), len(list_titles))

    if list_cmaps is not None:
        assert isinstance(list_cmaps, list)
        assert len(list_images) == len(list_cmaps), '%d imgs != %d cmaps' % (len(list_images), len(list_cmaps))

    num_images  = len(list_images)
    num_cols    = min(num_images, num_cols)
    num_rows    = int(num_images / num_cols) + (1 if num_images % num_cols != 0 else 0)

    # Create a grid of subplots.
    fig, axes = plt.subplots(num_rows, num_cols, figsize=figsize)
    
    # Create list of axes for easy iteration.
    if isinstance(axes, np.ndarray):
        list_axes = list(axes.flat)
    else:
        list_axes = [axes]

    for i in range(num_images):

        img    = list_images[i]
        title  = list_titles[i] if list_titles is not None else 'Image %d' % (i)
        cmap   = list_cmaps[i] if list_cmaps is not None else (None if img_is_color(img) else 'gray')
        
        list_axes[i].imshow(img, cmap=cmap)
        list_axes[i].set_title(title, fontsize=title_fontsize) 
        list_axes[i].grid(grid)

    for i in range(num_images, len(list_axes)):
        list_axes[i].set_visible(False)

    fig.tight_layout()
    _ = plt.show()

# %%
# code for displaying multiple images in one figure

#import libraries
import cv2
from matplotlib import pyplot as plt

# create figure
fig = plt.figure(figsize=(10, 7))

# setting values to rows and column variables
rows = 1
columns = 2
for i in range(113,140):
    # reading images

    x="[PATH TO IMAGE]"+str(i)+".jpg"
    y="[PATH TO IMAGE]"+str(i)+".jpg"
    print(y)
    Image1 = cv2.imread(x)
    Image2 = cv2.imread(y)

    # Adds a subplot at the 1st position
    fig.add_subplot(rows, columns, 1)

    # showing image
    plt.imshow(Image1[...,::-1])
    plt.axis('off')
    plt.title("mask")
    
    

    # Adds a subplot at the 2nd position
    fig.add_subplot(rows, columns, 2)

    # showing image
    plt.imshow(Image2[...,::-1])
    plt.axis('off')
    plt.title("pred_image")
    
    print("-------------------------------------------------------------------------------------------------------")

# Adds a subplot at the 3rd position
# Out:
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_113.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_114.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_115.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_116.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_117.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_118.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_119.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_120.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_121.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_122.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_123.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_124.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_125.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_126.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_127.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_128.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_129.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_130.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_131.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_132.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_133.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_134.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_135.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_136.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_137.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_138.jpg
# -------------------------------------------------------------------------------------------------------
# C:/Users/Adwait/Desktop/Nanavati dataset/file1 (1)/content/data/images/test/image_25_139.jpg
# -------------------------------------------------------------------------------------------------------
